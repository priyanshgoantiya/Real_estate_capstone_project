# %% [markdown]
# #` description of the columns Gurgaon real estate property`
#
# # **property_name**: The name or title of the property (e.g., "2 BHK Flat for Sale").
#
# ## link: A URL or link to the specific property listing on the website, providing more details.
#
# # society: The name of the residential society or building where the property is located (e.g., "ABC Apartments").
#
# # price: The listed price of the property, usually in the local currency (e.g., "₹50,00,000").
#
# # area: The total area of the property, typically in square feet or square meters (e.g., "1200 sqft").
#
# # areaWithType: The type of the area, such as "Super Built-up Area," "Carpet Area," etc., in addition to the area measurement (e.g., "Super Built-up Area: 1200 sqft").
#
# # bedRoom: The number of bedrooms in the property (e.g., "2").
#
# # bathroom: The number of bathrooms in the property (e.g., "2").
#
# # balcony: The number of balconies the property has (e.g., "1").
#
# # additionalRoom: The number of additional rooms, such as study rooms, storage rooms, etc. (e.g., "1").
#
# # address: The full address of the property, including the locality, city, and state (e.g., "123, MG Road, Bangalore, Karnataka").
#
# # floorNum: The floor number on which the property is located (e.g., "5th Floor").
#
# # facing: The direction in which the property faces (e.g., "East," "West," "North," "South").
#
# # agePossession: The age of the property or the time since possession was obtained (e.g., "5 years old" or "Immediate possession").
#
# # nearbyLocations: A list of nearby locations or landmarks close to the property (e.g., "School, Hospital, Metro Station").
#
# # description: A detailed description of the property, including features, amenities, and other relevant information (e.g., "Spacious 2 BHK flat with modular kitchen, 24/7 security").
#
# # furnishDetails: A list of details regarding the furnishings of the property, such as "Fully Furnished," "Semi Furnished," or "Unfurnished" (e.g., "Modular kitchen, wardrobes in bedrooms").
#
# # features: A list of key features of the property, such as amenities, specifications, or facilities (e.g., "Lift, 24/7 Water Supply, Gym").
#
# # rating: The rating or reviews given by users or buyers about the property, which may include scores or feedback (e.g., "4.5/5").
#
# # property_id: A unique identifier assigned to the property listing on the website (e.g., "12345").

# %%
## import library
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', None)

# %%
## load real estate Data
df=pd.read_csv('/content/flats_excel_cleaned.csv')

# %%
df.head()
# Out:
#                      property_name  \
# 0     2 BHK Flat in Krishna Colony
# 1        2 BHK Flat in Ashok Vihar
# 2              2 BHK Flat in Sohna
# 3  2 BHK Flat in Sector 61 Gurgaon
# 4  2 BHK Flat in Sector 92 Gurgaon
#
#                                                 link                 society  \
# 0  https://www.99acres.com/2-bhk-bedroom-apartmen...  maa bhagwati residency
# 1  https://www.99acres.com/2-bhk-bedroom-apartmen...            Apna Enclave
# 2  https://www.99acres.com/2-bhk-bedroom-apartmen...  Tulsiani Easy in Homes
# 3  https://www.99acres.com/2-bhk-bedroom-apartmen...     Smart World Orchard
# 4  https://www.99acres.com/2-bhk-bedroom-apartmen...        Parkwood Westend
#
#         price             area                            areaWithType  \
# 0      45 Lac   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)
# 1      50 Lac   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)
# ...

# %%
## shape
df.shape
# Out:
# (3009, 20)

# %%
## info. of real estate data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3009 entries, 0 to 3008
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3009 non-null   object
#  1   link             3009 non-null   object
#  2   society          3008 non-null   object
#  3   price            3008 non-null   object
#  4   area             2997 non-null   object
#  5   areaWithType     3009 non-null   object
#  6   bedRoom          3009 non-null   object
#  7   bathroom         3009 non-null   object
#  8   balcony          3009 non-null   object
#  9   additionalRoom   1695 non-null   object
#  10  address          3003 non-null   object
#  11  floorNum         3007 non-null   object
#  12  facing           2128 non-null   object
#  13  agePossession    3008 non-null   object
#  14  nearbyLocations  2914 non-null   object
#  15  description      3009 non-null   object
# ...

# %%
## duplicate rows
df.duplicated().sum()
# Out:
# 0

# %%
## missing values
df.isna().sum()
# Out:
# property_name         0
# link                  0
# society               1
# price                 1
# area                 12
# areaWithType          0
# bedRoom               0
# bathroom              0
# balcony               0
# additionalRoom     1314
# address               6
# floorNum              2
# facing              881
# agePossession         1
# nearbyLocations      95
# description           0
# furnishDetails      805
# features            414
# rating              332
# property_id           0
# dtype: int64

# %%
## columns to drop
df.drop(columns=['property_id','link'],inplace=True)

# %%
df.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave      50 Lac
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend      70 Lac
#
#               area                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# ...

# %% [markdown]
# #`Handle one column at a time to clean`

# %% [markdown]
# #`Society`

# %%
df['society'].value_counts().shape
# Out:
# (637,)

# %%
df['society']=df['society'].str.split(r'(?<=\D)(\d+\.\d+|\d+)(?=\W)').str.get(0)

# %%
df.sample(10)
# Out:
#                          property_name                      society  \
# 2711         4 BHK Flat in DLF Phase 5           DLF Royalton Tower
# 2759   3 BHK Flat in Sector 85 Gurgaon                   Godrej Air
# 350    3 BHK Flat in Sector 59 Gurgaon            Mahindra Luminare
# 2009     3 BHK Flat in Sector-33 Sohna           Godrej Nature Plus
# 1584  4 BHK Flat in Sector 102 Gurgaon      Adani M2K Oyster Grande
# 2133   3 BHK Flat in Sector 85 Gurgaon            Orris Aster Court
# 2071   2 BHK Flat in Sector 69 Gurgaon                  Tulip Lemon
# 1517           3 BHK Flat in Sultanpur                Empire estate
# 870          1 BHK Flat in Palam Vihar  Bestech Park View Residency
# 1844  3 BHK Flat in Sector 109 Gurgaon                   ATS Kocoon
#
#           price             area  \
# 2711  6.5 Crore  ₹ 22,108/sq.ft.
# 2759  2.6 Crore  ₹ 12,212/sq.ft.
# 350   5.5 Crore  ₹ 18,181/sq.ft.
# 2009  1.4 Crore  ₹ 15,124/sq.ft.
# 1584  2.5 Crore   ₹ 7,817/sq.ft.
# ...

# %%
## rename columns
df.rename(columns={'area':'Price_per_sqrt'},inplace=True)

# %% [markdown]
# #`Price`

# %%
df = df[df['price'] != 'price']

# %%
df=df[df['price'] != 'Price on Request']

# %%
df.shape
# Out:
# (2997, 18)

# %%
df['price']
# Out:
# 0            45 Lac
# 1            50 Lac
# 2            40 Lac
# 3        1.47 Crore
# 4            70 Lac
# 5            41 Lac
# 6           2 Crore
# 7         1.8 Crore
# 8         1.1 Crore
# 9        4.75 Crore
# 10           96 Lac
# 11           29 Lac
# 12       1.35 Crore
# 13           95 Lac
# 14           70 Lac
# 15       3.95 Crore
# 16           90 Lac
# 17       1.05 Crore
# 18              NaN
# 19        2.2 Crore
# 20       1.01 Crore
# 21       1.85 Crore
# 22           86 Lac
# 23       1.85 Crore
# 24       2.85 Crore
# 26           42 Lac
# 27       6.15 Crore
# 28       6.25 Crore
# 29           42 Lac
# 30       1.35 Crore
# 31        1.6 Crore
# 32       3.25 Crore
# 33           45 Lac
# 34           85 Lac
# 35           75 Lac
# 36           82 Lac
# 37        1.8 Crore
# 38        29.99 Lac
# 39           78 Lac
# 40          2 Crore
# 41           74 Lac
# 42        3.2 Crore
# 43        1.3 Crore
# 44           25 Lac
# 45           95 Lac
# ...

# %%
def treat_price(x):
    # Ensure the input is a string before processing
    if isinstance(x, str):
        # Normalize the string (remove spaces and handle uppercase/lowercase)
        x = x.strip().lower()

        # Split the string into number and unit part
        parts = x.split()

        if len(parts) == 2:
            num = float(parts[0])
            unit = parts[1]

            # Check for unit and convert accordingly
            if unit == 'lac':
                return np.round(num / 100, 2)  # Convert 'Lac' to 'Cr' by dividing by 100
            elif unit in ['crore', 'cr']:
                return np.round(num, 2)  # 'Crore' and 'Cr' are the same, keep as is
        else:
            # If there's no unit, return the number as is
            return np.round(float(parts[0]), 2)
    else:
        return x  # If it's not a string, return the value as is

# %%
df['price']=df['price'].apply(treat_price)
df['price']=df['price'].astype(float)

# %%
df.sample(10)
# Out:
#                          property_name                           society  \
# 1982               2 BHK Flat in Sohna                   Eldeco Accolade
# 2426   3 BHK Flat in Sector 76 Gurgaon              Whiteland Blissville
# 2155   3 BHK Flat in Sector 89 Gurgaon                     M3M Soulitude
# 2929               2 BHK Flat in Sohna                        MVN Athens
# 2536   3 BHK Flat in Sector 85 Gurgaon                        Godrej Air
# 1411  3 BHK Flat in Sector 82A Gurgaon                    DLF The Primus
# 408    3 BHK Flat in Sector 65 Gurgaon  Emaar MGF Emerald Floors Premier
# 2954         2 BHK Flat in Palam Vihar                ANSALS DUPLEX FLAT
# 1356  3 BHK Flat in Sector 106 Gurgaon                        Paras Dews
# 1246  3 BHK Flat in Sector 37C Gurgaon                Imperia The Esfera
#
#       price   Price_per_sqrt  \
# 1982   0.96   ₹ 6,554/sq.ft.
# 2426   1.92  ₹ 11,500/sq.ft.
# 2155   1.14   ₹ 8,000/sq.ft.
# 2929   0.25   ₹ 5,189/sq.ft.
# ...

# %% [markdown]
# #`Price_per_sqrt`

# %%
df['Price_per_sqrt']=df['Price_per_sqrt'].str.replace('/sq.ft.','').str.replace(',','').str.replace('₹','').str.strip()
df['Price_per_sqrt']=df['Price_per_sqrt'].astype(float)

# %% [markdown]
# #`area with type`

# %%
## Need more attension
df['areaWithType'].value_counts()
# Out:
# areaWithType
# Super Built up area 1578(146.6 sq.m.)                                                                                           17
# Super Built up area 1350(125.42 sq.m.)                                                                                          17
# Super Built up area 1950(181.16 sq.m.)Carpet area: 1161 sq.ft. (107.86 sq.m.)                                                   17
# Super Built up area 1650(153.29 sq.m.)Carpet area: 1022.58 sq.ft. (95 sq.m.)                                                    15
# Super Built up area 2010(186.74 sq.m.)                                                                                          14
# Super Built up area 2150(199.74 sq.m.)                                                                                          12
# Super Built up area 1950(181.16 sq.m.)                                                                                          11
# ...

# %% [markdown]
# #`bedRoom`

# %%
df['bedRoom']=df['bedRoom'].str.replace('Bedrooms','').str.replace('Bedroom','').str.strip()
df['bedRoom']=df['bedRoom'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2997 entries, 0 to 3008
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    2997 non-null   object
#  1   society          2996 non-null   object
#  2   price            2996 non-null   float64
#  3   Price_per_sqrt   2996 non-null   float64
#  4   areaWithType     2997 non-null   object
#  5   bedRoom          2997 non-null   int64
#  6   bathroom         2997 non-null   object
#  7   balcony          2997 non-null   object
#  8   additionalRoom   1692 non-null   object
#  9   address          2991 non-null   object
#  10  floorNum         2995 non-null   object
#  11  facing           2123 non-null   object
#  12  agePossession    2996 non-null   object
#  13  nearbyLocations  2906 non-null   object
#  14  description      2997 non-null   object
#  15  furnishDetails   2200 non-null   object
#  16  features         2590 non-null   object
# ...

# %% [markdown]
# #`bathroom`

# %%
df['bathroom']=df['bathroom'].str.replace('Bathrooms','').str.replace('Bathroom','').str.strip()
df['bathroom']= df['bathroom'].astype(int)

# %% [markdown]
# #`balcony`

# %%
df['balcony']=df['balcony'].str.replace(r'No Balcony', '0', regex=True).str.replace('+','').str.replace('Balconies',
                                                                                          '').str.replace('Balcony','').str.strip()

# %%
df['balcony']=df['balcony'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2997 entries, 0 to 3008
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    2997 non-null   object
#  1   society          2996 non-null   object
#  2   price            2996 non-null   float64
#  3   Price_per_sqrt   2996 non-null   float64
#  4   areaWithType     2997 non-null   object
#  5   bedRoom          2997 non-null   int64
#  6   bathroom         2997 non-null   int64
#  7   balcony          2997 non-null   int64
#  8   additionalRoom   1692 non-null   object
#  9   address          2991 non-null   object
#  10  floorNum         2995 non-null   object
#  11  facing           2123 non-null   object
#  12  agePossession    2996 non-null   object
#  13  nearbyLocations  2906 non-null   object
#  14  description      2997 non-null   object
#  15  furnishDetails   2200 non-null   object
#  16  features         2590 non-null   object
# ...

# %% [markdown]
# #`additionalRoom`

# %%
df['additionalRoom'].value_counts(dropna=False)
# Out:
# additionalRoom
# NaN                                              1305
# Servant Room                                      629
# Study Room                                        232
# Others                                            179
# Pooja Room                                        132
# Study Room,Servant Room                            81
# Store Room                                         76
# Pooja Room,Servant Room                            60
# Servant Room,Others                                52
# Servant Room,Pooja Room                            30
# Study Room,Others                                  27
# Pooja Room,Study Room,Servant Room,Others          25
# Pooja Room,Study Room,Servant Room                 24
# Servant Room,Store Room                            19
# Pooja Room,Study Room                              13
# Pooja Room,Study Room,Servant Room,Store Room      12
# Study Room,Pooja Room                               8
# ...

# %%
df['additionalRoom']=df['additionalRoom'].fillna('Not available')

# %%
# def additionalRoom_processing(x):
#   if x =='Not available':
#     return 0
#   else:
#     return 1
# df['additionalRoom']=df['additionalRoom'].apply(additionalRoom_processing)
# df['additionalRoom']=df['additionalRoom'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2997 entries, 0 to 3008
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    2997 non-null   object
#  1   society          2996 non-null   object
#  2   price            2996 non-null   float64
#  3   Price_per_sqrt   2996 non-null   float64
#  4   areaWithType     2997 non-null   object
#  5   bedRoom          2997 non-null   int64
#  6   bathroom         2997 non-null   int64
#  7   balcony          2997 non-null   int64
#  8   additionalRoom   2997 non-null   object
#  9   address          2991 non-null   object
#  10  floorNum         2995 non-null   object
#  11  facing           2123 non-null   object
#  12  agePossession    2996 non-null   object
#  13  nearbyLocations  2906 non-null   object
#  14  description      2997 non-null   object
#  15  furnishDetails   2200 non-null   object
#  16  features         2590 non-null   object
# ...

# %% [markdown]
# #`floorNum `

# %%
df['floorNum'].isna().sum()
# Out:
# 2

# %%
df['floorNum']=df['floorNum'].str.split(' ').str.get(0).str.replace(r'Lower','0',regex=True).str.replace(r'Ground','0',regex=True).str.replace(r'Basement',
                '-1',regex=True).replace(r'[A-Za-z]','',regex=True).str.strip()

# %%
df['floorNum']=df['floorNum'].astype(float)

# %% [markdown]
# #`facing`

# %%
df['facing'].value_counts(dropna=False)
# Out:
# facing
# NaN           874
# North-East    505
# East          490
# North         301
# South         203
# West          183
# North-West    162
# South-East    144
# South-West    135
# Name: count, dtype: int64

# %%
df['facing'].fillna('NA',inplace=True)
# Out:
# <ipython-input-37-e6ba103970bd>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['facing'].fillna('NA',inplace=True)

# %%
# we can calculate area of flat
df['Area']=(df['price']*10000000)/df['Price_per_sqrt']

# %%
# Move 'column2' to the first position
col = df.pop('Area')
df.insert(4, 'Area', col)

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave   0.50
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend   0.70
#
#    Price_per_sqrt         Area                            areaWithType  \
# 0          5000.0   900.000000          Carpet area: 900 (83.61 sq.m.)
# 1          7692.0   650.026001          Carpet area: 650 (60.39 sq.m.)
# 2          6722.0   595.060994          Carpet area: 595 (55.28 sq.m.)
# 3         12250.0  1200.000000        Carpet area: 1200 (111.48 sq.m.)
# 4          5204.0  1345.119139  Super Built up area 1345(124.95 sq.m.)
#
#    bedRoom  bathroom  balcony additionalRoom  \
# 0        2         2        1  Not available
# 1        2         2        1  Not available
# ...

# %%
df.insert(loc=1,column='Property_type',value='flat')

# %%
df.shape
# Out:
# (2997, 20)

# %%
df.to_csv('flats_cleaned_csv',index=False)
